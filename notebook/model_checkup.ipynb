# %%
import pandas as pd

# %%
test = pd.read_csv('./skill2vec_1k.csv', header = None)

# %%
test = test.transpose()
test.columns = test.iloc[1]
test = test.iloc[2:, :]

# %%
test
# Out:
# 1                    Rest       capital_markets                        r12  \
# 2    Communication Skills               lending  good communication skills
# 3             Geo Fencing     trading_solutions              communication
# 4               Core Java    financial_services      functional consultant
# 5             Android SDK    investment_banking                     oracle
# 6            Web Services  front_office_trading                oracle apps
# ..                    ...                   ...                        ...
# 956                   NaN                   NaN                        NaN
# 957                   NaN                   NaN                        NaN
# 958                   NaN                   NaN                        NaN
# 959                   NaN                   NaN                        NaN
# 960                   NaN                   NaN                        NaN
#
# 1              quotation                 prime            L3  \
# ...
